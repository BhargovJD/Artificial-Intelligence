# %%
name = "Bhargov Jyoti Das"
print(name.lower())
# Out:
# bhargov jyoti das

# %%
sentence_list = ['Hi',
                 'My name is',
                  'Bhargov Jyoti Das'
                 ]
lower_sentence_list = [ x.lower() for x in sentence_list]
print(lower_sentence_list)
# Out:
# ['hi', 'my name is', 'bhargov jyoti das']
